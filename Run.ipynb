# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/u2pr311/bin/python

# %%
# !cd "/Users/zakerhussainrasooli/Downloads/U 2-NLP/NLP"
# !/opt/anaconda3/envs/u2pr311/bin/python -m pip install streamlit
# !/opt/anaconda3/envs/u2pr311/bin/python -m streamlit run app/streamlit_app.py
# Out:
# ...
# ^C
# Exception ignored in: <module 'threading' from '/opt/anaconda3/envs/u2pr311/lib/python3.11/threading.py'>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/u2pr311/lib/python3.11/threading.py", line 1560, in _shutdown
#     atexit_call()
#   File "/opt/anaconda3/envs/u2pr311/lib/python3.11/concurrent/futures/thread.py", line 31, in _python_exit
#     t.join()
#   File "/opt/anaconda3/envs/u2pr311/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/opt/anaconda3/envs/u2pr311/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt:
